# %% [markdown]
# # Exploração de dados / Importação de bibliotecas

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
metadata = pd.read_csv("datasets/movies_metadata.csv")

metadata
# Out:
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_22312\2569751666.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv("datasets/movies_metadata.csv")
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %% [markdown]
# # Recomendação simples (ranking)

# %%
# Definindo C (média das avaliações de todos os filmes do dataset)

C = metadata['vote_average'].mean()

print(C)
# Out:
# 5.618207215134185

# %%
# Definindo M (quantidade mínima de votos necessários p/ um filme ser considerado)

m = metadata['vote_count'].quantile(0.90)

print(m)
# Out:
# 160.0

# %%
q_movies = metadata.copy().loc[metadata['vote_count'] >= m]
print(q_movies.shape)
# Out:
# (4555, 24)

# %%
metadata.shape
# Out:
# (45466, 24)

# %%
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']

    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
q_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# 8      False                                                NaN  35000000
# ...      ...                                                ...       ...
# 45177  False  {'id': 442352, 'name': 'Brice Collection', 'po...         0
# 45204  False                                                NaN         0
# 45258  False  {'id': 466463, 'name': 'Descendants Collection...         0
# 45265  False                                                NaN         0
# 45343  False  {'id': 52888, 'name': 'The Visitors Collection...  25868826
#
#                                                   genres  \
# ...

# %%
q_movies = q_movies.sort_values('score', ascending=False)

q_movies
# Out:
#        adult                              belongs_to_collection     budget  \
# 314    False                                                NaN   25000000
# 834    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 10309  False                                                NaN   13200000
# 12481  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# 2843   False                                                NaN   63000000
# ...      ...                                                ...        ...
# 9710   False  {'id': 43072, 'name': 'The Mask Collection', '...   84000000
# 12911  False                                                NaN   25000000
# 3471   False                                                NaN   44000000
# 11557  False                                                NaN   20000000
# 13566  False                                                NaN  100000000
#
#                                                   genres  \
# ...

# %% [markdown]
# # Sistema de recomendação por conteúdo

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words = 'english')

metadata['overview'] = metadata['overview'].fillna('')

tfidf_matrix = tfidf.fit_transform(metadata['overview'])

# %%
tfidf.get_feature_names_out()[1:10]
# Out:
# array(['000', '000km', '000th', '001', '006', '007', '008', '009', '0093'],
#       dtype=object)

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(metadata.index, index=metadata['title']).drop_duplicates()

# %%
indices[:10]
# Out:
# title
# Toy Story                      0
# Jumanji                        1
# Grumpier Old Men               2
# Waiting to Exhale              3
# Father of the Bride Part II    4
# Heat                           5
# Sabrina                        6
# Tom and Huck                   7
# Sudden Death                   8
# GoldenEye                      9
# dtype: int64

# %%
def get_recommendations(title, cosine_sim=cosine_sim):

    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim(idx)))

    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)

    sim_scores = sim_scores[1:11]

    movie_indices = [i[0] for i in sim_scores]

    return metadata['title'].iloc[movie_indices]
